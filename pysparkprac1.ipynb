# %%
#!pip install PySpark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.3 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for PySpark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=523f7d001f3a04718d5b3128ff5aac7321952849ba16a0bdd1df9e21a461e841
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built PySpark
# ...

# %%
import pyspark

# %%
import pandas as pd
d = {("Guru",10),("Gta",11),("Gra",12)}
df = pd.DataFrame(d)

# %%
df.columns = ['Name', 'Age']

# %%
df.to_csv('test.csv')

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Prac').getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/16 06:36:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://b75bc4b35fe9:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Prac</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pys = spark.read.csv('test.csv')

# %%
df_pys
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string]

# %%
df_pys.show()
# Out:
# +----+----+---+
# | _c0| _c1|_c2|
# +----+----+---+
# |NULL|Name|Age|
# |   0| Gta| 11|
# |   1|Guru| 10|
# |   2| Gra| 12|
# +----+----+---+

# %%
df_pys=spark.read.option('header','true').csv('test.csv')

# %%
type(df_pys)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pys.head()
# Out:
# 24/05/16 06:49:30 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , Name, Age
#  Schema: _c0, Name, Age
# Expected: _c0 but found:
# CSV file: file:///kaggle/working/test.csv
# Row(_c0='0', Name='Gta', Age='11')

# %%
df_pys.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Age: string (nullable = true)
